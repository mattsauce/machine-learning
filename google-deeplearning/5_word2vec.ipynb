# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'anarchism', 'originated', 'term', 'originated', 'as', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.071881
# Nearest to its: smiths, gene, glide, aegeus, contamination, flies, sbc, mini,
# Nearest to UNK: macintoshes, benevolence, speleology, proselytes, ccr, vultures, soliloquy, adventurer,
# Nearest to years: worm, zebulon, thrown, shielded, seperate, vested, sanhedrin, tumour,
# Nearest to system: souvenirs, invasion, dialing, vulnerabilities, wedgwood, pyrrhus, suo, beacons,
# Nearest to some: communicative, closest, showcasing, deptford, formation, hydraulic, ajmer, moria,
# Nearest to an: adler, sterne, yard, apply, sda, pickled, delft, showcases,
# Nearest to known: katanga, pogroms, sms, teammate, vostok, elbert, jaime, boson,
# Nearest to also: levi, babcock, whirlpool, executors, derails, kul, cahiers, baikonur,
# Nearest to he: noailles, inanimate, dope, catal, growing, kidnapped, transporter, lambdamoo,
# Nearest to s: ralph, mitch, tooth, diagnoses, antonio, shmuel, passed, tehran,
# Nearest to from: endow, exposed, orloff, inwo, military, guardia, andrey, physiological,
# Nearest to that: eusebio, asylum, menahem, audible, housekeeping, lynched, appellant, dod,
# Nearest to into: macedon, kung, adrenaline, armory, financing, utah, vodka, vanir,
# Nearest to war: thorough, hypnotism, antiprisms, ariadne, xyz, longhair, beers, hellenism,
# Nearest to after: plebiscite, containers, samaritans, caricatures, oic, speedway, enacting, especially,
# Nearest to than: slam, scrat, yearly, baraka, hispanics, svc, leninist, abrasive,
# Average loss at step 2000: 4.363901
# Average loss at step 4000: 3.864427
# Average loss at step 6000: 3.795708
# Average loss at step 8000: 3.687130
# Average loss at step 10000: 3.617499
# Nearest to its: the, phospholipid, his, their, fpgas, hexen, transmit, control,
# Nearest to UNK: tupac, chickie, sheryl, assisting, onlookers, masorti, jfif, mall,
# Nearest to years: thrown, zebulon, tumour, comparative, worm, signage, grille, jinn,
# Nearest to system: suo, caplan, bak, humor, character, magnon, route, mauss,
# Nearest to some: goldfish, showcasing, each, ajmer, various, many, appomattox, lexicon,
# Nearest to an: the, delft, ergonomics, nanometer, sterne, gabonese, equalized, compress,
# Nearest to known: sms, intolerance, such, medicaid, dictators, katanga, we, seen,
# Nearest to also: humor, often, now, he, fifo, it, which, executors,
# Nearest to he: it, who, they, she, there, also, you, heaps,
# Nearest to s: and, his, unhcr, or, oiled, stripes, the, commune,
# Nearest to from: in, at, and, orloff, by, exposed, of, around,
# Nearest to that: which, it, where, whose, who, what, executors, plumes,
# Nearest to into: demonstrates, palmer, ionization, camino, new, aitken, autonomous, sideways,
# Nearest to war: shuttle, lemma, thorough, unprofitable, progenitors, koo, unremarkable, beers,
# Nearest to after: plebiscite, before, rigorous, seller, vindication, against, murmur, with,
# Nearest to than: hispanics, hydrochloric, xxxiii, scrat, fansite, rube, seneca, yearly,
# Average loss at step 12000: 3.606836
# Average loss at step 14000: 3.570642
# Average loss at step 16000: 3.409787
# Average loss at step 18000: 3.454938
# Average loss at step 20000: 3.543786
# Nearest to its: their, his, the, control, her, fpgas, some, abstracted,
# Nearest to UNK: stanbul, antibody, skip, greater, clubhouse, awards, intruders, apse,
# Nearest to years: thrown, tumour, zebulon, comparative, ringers, homeschooling, derision, jinn,
# Nearest to system: suo, bak, humor, invasion, character, svetlana, caplan, professed,
# Nearest to some: many, all, these, several, various, their, any, incipient,
# Nearest to an: the, sterne, kristina, nanometer, ebony, gabonese, deals, compress,
# Nearest to known: such, sms, used, seen, intolerance, well, dictators, bofh,
# Nearest to also: now, which, often, still, not, amine, presenter, sometimes,
# Nearest to he: it, she, they, who, there, never, which, certainly,
# Nearest to s: normand, commune, hemphill, unearthed, stripes, flicker, deleted, algol,
# Nearest to from: in, at, into, and, between, through, over, by,
# Nearest to that: which, what, where, however, plumes, it, also, penetration,
# Nearest to into: demonstrates, from, ionization, through, shorter, palmer, szl, camino,
# Nearest to war: machining, shuttle, slobodan, progenitors, technically, lemma, unprofitable, bryson,
# Nearest to after: before, plebiscite, when, with, rigorous, gleaned, at, stalker,
# Nearest to than: or, hydrochloric, rube, hispanics, vaz, motors, scrat, much,
# Average loss at step 22000: 3.503735
# Average loss at step 24000: 3.489396
# Average loss at step 26000: 3.482470
# Average loss at step 28000: 3.479786
# Average loss at step 30000: 3.504403
# Nearest to its: their, the, his, her, control, fpgas, misrepresenting, our,
# Nearest to UNK: officially, h, iqs, realise, certificate, prince, j, rn,
# Nearest to years: year, days, skipped, zebulon, months, comparative, eschenbach, convocation,
# Nearest to system: svetlana, humor, invasion, grade, systems, bak, suo, marianne,
# Nearest to some: many, these, several, all, any, those, various, their,
# Nearest to an: compress, nanometer, sterne, gabonese, pentagram, opcode, delft, ebony,
# Nearest to known: used, such, seen, sms, well, intolerance, regarded, defined,
# Nearest to also: often, still, now, sometimes, lderlin, it, which, who,
# Nearest to he: she, it, they, who, there, never, we, freudian,
# Nearest to s: deleted, his, soriano, haut, lcm, squat, min, commune,
# Nearest to from: into, through, after, in, inline, during, on, by,
# Nearest to that: which, however, this, what, where, falkland, menahem, everett,
# Nearest to into: through, from, ionization, demonstrates, shorter, palmer, camino, szl,
# Nearest to war: machining, pedigree, beers, ritz, technically, unremarkable, lemma, zaghawa,
# Nearest to after: before, when, during, from, plebiscite, in, at, through,
# Nearest to than: much, for, hydrochloric, tissot, kylix, rube, empress, fansite,
# Average loss at step 32000: 3.499740
# Average loss at step 34000: 3.494150
# Average loss at step 36000: 3.457229
# Average loss at step 38000: 3.301749
# Average loss at step 40000: 3.432981
# Nearest to its: their, his, her, the, fpgas, rusher, control, our,
# Nearest to UNK: physician, robins, barclay, ach, mart, b, and, bob,
# Nearest to years: days, months, year, times, skipped, jinn, convocation, eschenbach,
# Nearest to system: systems, invasion, svetlana, bak, social, marianne, route, grade,
# Nearest to some: many, these, several, any, those, each, their, both,
# Nearest to an: dl, compress, nanometer, pentagram, lausanne, surfaces, sterne, mosiah,
# Nearest to known: used, such, seen, sms, well, regarded, intolerance, defined,
# Nearest to also: often, still, now, which, sometimes, lderlin, typically, who,
# Nearest to he: she, it, they, there, who, we, i, never,
# Nearest to s: shenzhen, osce, his, my, mamoru, deleted, dispelling, mvp,
# Nearest to from: into, through, in, over, after, during, at, tius,
# Nearest to that: which, however, this, what, because, where, doubtless, biloxi,
# Nearest to into: through, from, ionization, shorter, demonstrates, palmer, bagpuss, steak,
# Nearest to war: technically, beers, machining, unprofitable, pores, delivered, ritz, pedigree,
# Nearest to after: before, during, when, from, despite, plebiscite, octavian, daleks,
# Nearest to than: much, or, measure, restrained, gumbo, hydrochloric, empress, kylix,
# Average loss at step 42000: 3.435486
# Average loss at step 44000: 3.454003
# Average loss at step 46000: 3.452346
# Average loss at step 48000: 3.356447
# Average loss at step 50000: 3.380110
# Nearest to its: their, his, the, her, whose, our, fpgas, wielding,
# Nearest to UNK: sabra, j, acid, com, virginian, planners, mehmed, neo,
# Nearest to years: days, months, times, year, skipped, convocation, utilising, cairn,
# Nearest to system: systems, marianne, svetlana, grade, invasion, bak, card, route,
# Nearest to some: many, several, these, any, those, certain, the, their,
# Nearest to an: compress, gabonese, dl, sterne, opcode, the, access, pentagram,
# Nearest to known: used, such, regarded, seen, possible, sms, intolerance, defined,
# Nearest to also: often, still, now, which, slept, sometimes, usually, who,
# Nearest to he: she, it, they, who, there, never, contrasting, i,
# Nearest to s: squat, loyalist, shenzhen, marischal, and, quinlan, maria, was,
# Nearest to from: into, through, in, between, at, hypothyroidism, after, tius,
# Nearest to that: which, however, what, where, because, this, executors, martian,
# Nearest to into: through, from, after, shorter, across, palmer, ionization, behind,
# Nearest to war: beers, altering, ritz, pedigree, pores, machining, technically, unprofitable,
# Nearest to after: before, when, during, while, despite, through, into, saw,
# Nearest to than: or, much, kylix, measure, equipping, restrained, even, gumbo,
# Average loss at step 52000: 3.440724
# Average loss at step 54000: 3.422334
# Average loss at step 56000: 3.434056
# Average loss at step 58000: 3.394763
# Average loss at step 60000: 3.395545
# Nearest to its: their, the, his, her, whose, abstracted, fpgas, our,
# Nearest to UNK: extinct, scruggs, anomalous, shrouded, geschichte, carrero, protestant, robotech,
# Nearest to years: days, months, year, times, decades, minutes, inhabitants, centuries,
# Nearest to system: systems, card, invasion, sustaining, gravely, social, network, caucus,
# Nearest to some: many, several, these, those, all, any, this, certain,
# Nearest to an: sterne, compress, nanometer, ergonomics, sennacherib, jody, surfaces, flashback,
# Nearest to known: used, such, regarded, seen, well, possible, defined, sms,
# Nearest to also: still, now, often, sometimes, below, currently, which, commonly,
# Nearest to he: she, it, they, who, there, never, we, finally,
# Nearest to s: whose, geese, hangul, advocacy, lcm, soriano, infallible, crazed,
# Nearest to from: into, through, tius, physiological, giza, in, since, between,
# Nearest to that: which, this, however, what, executors, doing, because, heme,
# Nearest to into: through, from, ionization, within, across, behind, belarusian, shorter,
# Nearest to war: altering, beers, pedigree, math, ritz, unprofitable, technically, regalia,
# Nearest to after: before, during, when, while, despite, under, daleks, until,
# Nearest to than: or, much, and, restrained, but, equipping, kylix, scrat,
# Average loss at step 62000: 3.241926
# Average loss at step 64000: 3.253899
# Average loss at step 66000: 3.406597
# Average loss at step 68000: 3.401427
# Average loss at step 70000: 3.361531
# Nearest to its: their, the, his, her, whose, abstracted, our, monomers,
# Nearest to UNK: storehouses, demonic, beat, pacified, appendicitis, spinners, xinhua, shrews,
# Nearest to years: days, months, year, decades, times, minutes, centuries, inhabitants,
# Nearest to system: systems, program, network, policy, card, sustaining, undamaged, process,
# Nearest to some: many, several, these, any, all, those, various, other,
# Nearest to an: dl, sterne, compress, peasant, pentagram, sennacherib, the, showcases,
# Nearest to known: used, seen, regarded, such, defined, described, viewed, intolerance,
# Nearest to also: still, now, often, which, sometimes, usually, commonly, currently,
# Nearest to he: she, it, they, there, who, never, we, telstra,
# Nearest to s: whose, lcm, shenzhen, viable, and, deleted, soriano, hemphill,
# Nearest to from: through, into, in, mourns, between, gaston, tius, amati,
# Nearest to that: which, however, what, this, executors, but, because, typically,
# Nearest to into: through, from, ionization, within, belarusian, shorter, across, szl,
# Nearest to war: altering, ritz, technically, unprofitable, consultation, beers, machining, pedigree,
# Nearest to after: before, during, despite, when, while, until, through, daleks,
# Nearest to than: or, much, kylix, equipping, alliances, but, even, restrained,
# Average loss at step 72000: 3.375032
# Average loss at step 74000: 3.343426
# Average loss at step 76000: 3.319548
# Average loss at step 78000: 3.355087
# Average loss at step 80000: 3.377460
# Nearest to its: their, his, her, the, your, our, whose, abstracted,
# Nearest to UNK: im, ozzy, williams, pierre, earths, mandibles, stanbul, richmond,
# Nearest to years: days, months, year, times, decades, minutes, centuries, weeks,
# Nearest to system: systems, program, card, network, crested, caucus, process, xk,
# Nearest to some: many, several, these, any, those, certain, various, most,
# Nearest to an: sterne, compress, dl, nanometer, excluded, ergonomics, paleontologists, deals,
# Nearest to known: used, regarded, seen, defined, such, called, described, viewed,
# Nearest to also: now, still, often, sometimes, which, here, ayahuasca, never,
# Nearest to he: she, it, they, who, there, never, quickly, telstra,
# Nearest to s: issn, isbn, huntingford, soriano, leakey, marischal, stadia, whose,
# Nearest to from: through, into, after, jungle, mourns, between, shogunate, in,
# Nearest to that: however, which, where, this, what, executors, how, telegrams,
# Nearest to into: through, from, within, ionization, across, using, belarusian, upon,
# Nearest to war: altering, consultation, ritz, technically, machining, pedigree, beers, apocryphal,
# Nearest to after: before, during, despite, when, while, though, until, without,
# Nearest to than: or, while, much, even, but, restrained, far, kylix,
# Average loss at step 82000: 3.404710
# Average loss at step 84000: 3.410732
# Average loss at step 86000: 3.389001
# Average loss at step 88000: 3.351958
# Average loss at step 90000: 3.367694
# Nearest to its: their, his, her, the, whose, your, abstracted, our,
# Nearest to UNK: ann, rzburg, ilyich, intimately, prom, certificate, bk, invariance,
# Nearest to years: days, months, decades, minutes, year, centuries, times, weeks,
# Nearest to system: systems, process, program, interferon, network, undamaged, xk, coil,
# Nearest to some: many, several, these, any, all, certain, those, most,
# Nearest to an: ergonomics, sterne, compress, littoral, nanometer, disambiguation, garbo, another,
# Nearest to known: used, regarded, such, seen, described, defined, called, recognized,
# Nearest to also: now, often, still, sometimes, never, which, usually, ever,
# Nearest to he: she, it, they, there, who, later, but, telstra,
# Nearest to s: whose, isbn, his, huntingford, arse, nielsen, sheik, subservient,
# Nearest to from: through, into, during, after, between, towards, italiano, looksmart,
# Nearest to that: which, however, what, but, plumes, this, where, therefore,
# Nearest to into: through, from, ionization, within, belarusian, bags, using, camino,
# Nearest to war: altering, unprofitable, apocryphal, ritz, consultation, weishaupt, sandwiched, sharing,
# Nearest to after: before, during, when, despite, until, while, through, without,
# Nearest to than: or, equipping, much, restrained, patois, callimico, breuer, somewhat,
# Average loss at step 92000: 3.405399
# Average loss at step 94000: 3.255304
# Average loss at step 96000: 3.358528
# Average loss at step 98000: 3.245193
# Average loss at step 100000: 3.360353
# Nearest to its: their, his, the, her, whose, your, abstracted, our,
# Nearest to UNK: cath, rationalisation, rzburg, worthless, mateo, demonic, abate, ges,
# Nearest to years: days, months, year, decades, minutes, centuries, times, weeks,
# Nearest to system: systems, process, program, model, gravely, device, network, rr,
# Nearest to some: many, several, these, certain, any, all, their, those,
# Nearest to an: another, compress, sterne, sennacherib, pentagram, jody, nanometer, dependents,
# Nearest to known: regarded, seen, such, described, used, defined, viewed, possible,
# Nearest to also: now, still, never, often, sometimes, actually, traditionally, generally,
# Nearest to he: she, it, they, there, who, we, never, telstra,
# Nearest to s: whose, his, amounting, issn, isbn, deleted, my, the,
# Nearest to from: in, through, into, looksmart, tius, mourns, igbo, during,
# Nearest to that: which, however, what, telegrams, executors, who, where, because,
# Nearest to into: through, within, from, ionization, using, bags, across, in,
# Nearest to war: altering, apocryphal, act, consultation, weishaupt, unprofitable, ritz, sharing,
# Nearest to after: before, during, when, despite, without, while, until, although,
# Nearest to than: or, much, equipping, restrained, dg, adjutant, even, kylix,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_labels, batch_data  = generate_batch(
      batch_size, num_skips, skip_window)
    batch_data = batch_data.reshape((batch_size,))
    batch_labels = batch_labels.reshape((batch_size, 1))
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.421291
# Nearest to its: transformed, smiley, trimmed, unaspirated, foxe, pronounced, unionists, bored,
# Nearest to UNK: reserving, hardness, auteurs, anthropos, artefact, dci, impairs, nakano,
# Nearest to years: bacardi, haynes, tms, commissioned, postmodernist, nonstandard, yeo, flockhart,
# Nearest to system: karachi, alley, leszek, scar, usmc, predominantly, tabled, pointe,
# Nearest to some: industrialized, convinces, pelletier, yuma, fornication, tirthankaras, milit, admiration,
# Nearest to an: lyceum, fragmentary, bentsen, eugenic, minsk, praises, gravis, baseball,
# Nearest to known: inlets, carolla, newsweek, citt, amplify, parenthesis, speyer, gigantopithecus,
# Nearest to also: heavy, toei, juxtaposition, pls, interrogations, harald, prelude, duress,
# Nearest to he: exerts, raytheon, officio, anderson, bombay, quarterly, culminates, benedictine,
# Nearest to s: farrell, introspection, hilda, circles, unexplained, sent, wedgwood, coaster,
# Nearest to from: globular, coppersmith, addicts, trentino, breakage, fie, thucydides, observance,
# Nearest to that: athabasca, harbour, stem, fixation, cetacea, gloucester, kab, mania,
# Nearest to into: arsacid, combat, radiation, superpowered, luxuries, bradbury, lars, waterfalls,
# Nearest to war: laureate, appealed, lester, stimulants, missing, midshipman, apuleius, bodybuilding,
# Nearest to after: shinoda, moore, appended, pronunciation, townshend, sprawl, consilience, extremely,
# Nearest to than: liberation, reelection, windshield, mccourt, cabrera, rttemberg, ttir, first,
# Average loss at step 2000: 4.382285
# Average loss at step 4000: 3.879433
# Average loss at step 6000: 3.800217
# Average loss at step 8000: 3.757644
# Average loss at step 10000: 3.628103
# Nearest to its: their, the, his, pubmed, unaspirated, mccall, warners, fusing,
# Nearest to UNK: dect, youngster, quad, atman, tui, electromotive, sc, gallery,
# Nearest to years: bacardi, haynes, westchester, commissioned, spokane, codeine, disowned, sappho,
# Nearest to system: draper, petite, frequencies, usmc, goidelic, shakyamuni, eazy, predominantly,
# Nearest to some: many, industrialized, crippled, discoveries, these, milit, assassinating, diversification,
# Nearest to an: williams, fragmentary, praises, tychonoff, caecilius, celebrated, shoghi, herse,
# Nearest to known: inlets, carolla, distortions, citt, gigantopithecus, geller, used, amplify,
# Nearest to also: often, interrogations, merck, chimpanzees, become, which, lugosi, owing,
# Nearest to he: it, they, who, she, exerts, savoy, largely, rh,
# Nearest to s: serpent, and, zero, his, approximated, analytic, marginally, palpitations,
# Nearest to from: in, on, and, to, servicemen, globular, of, identifiers,
# Nearest to that: which, this, will, poses, not, above, tetra, ascends,
# Nearest to into: luxuries, to, including, from, trinitarian, stoic, annulled, arsacid,
# Nearest to war: lester, stimulants, midshipman, appealed, laureate, fits, jama, apuleius,
# Nearest to after: appended, shinoda, townshend, countdown, moore, responded, bouvines, pronunciation,
# Nearest to than: windshield, zoff, ind, reelection, promised, opiates, liberation, esb,
# Average loss at step 12000: 3.576998
# Average loss at step 14000: 3.615076
# Average loss at step 16000: 3.584079
# Average loss at step 18000: 3.571339
# Average loss at step 20000: 3.545490
# Nearest to its: their, the, his, embarked, ahab, doublespeak, ades, inaccurate,
# Nearest to UNK: intransitive, browse, detained, orbital, shingles, barbagia, dinosauria, benevolence,
# Nearest to years: haynes, times, spokane, bacardi, codeine, chthonic, associates, kyo,
# Nearest to system: frequencies, draper, anthropologists, petite, churchmen, sclc, declined, usmc,
# Nearest to some: many, these, several, their, gheg, any, milit, all,
# Nearest to an: celebrated, the, tychonoff, bonner, strangely, kazantzakis, contending, rubbing,
# Nearest to known: used, seen, just, inlets, such, shown, nomination, carolla,
# Nearest to also: often, which, sometimes, monsoon, still, not, it, now,
# Nearest to he: it, she, they, who, there, largely, rh, boroughs,
# Nearest to s: and, his, prompt, kets, hells, orissa, functionalists, mehrgarh,
# Nearest to from: into, in, by, observance, between, story, globular, anoa,
# Nearest to that: which, however, who, poses, this, vanquish, also, it,
# Nearest to into: from, between, stoic, through, to, luxuries, spawn, with,
# Nearest to war: appealed, crony, fits, midshipman, lester, abraham, stimulants, formalised,
# Nearest to after: appended, shinoda, trinitarian, before, penned, chatting, lieutenants, countdown,
# Nearest to than: windshield, sufferings, opiates, ind, isp, but, zoff, reelection,
# Average loss at step 22000: 3.533407
# Average loss at step 24000: 3.441289
# Average loss at step 26000: 3.420281
# Average loss at step 28000: 3.473282
# Average loss at step 30000: 3.405096
# Nearest to its: their, the, his, her, embarked, doublespeak, removing, trust,
# Nearest to UNK: dmt, sarcophagi, tui, robert, unn, p, egoist, resorted,
# Nearest to years: times, days, year, spokane, haynes, gana, generations, chthonic,
# Nearest to system: frequencies, usmc, draper, scar, churchmen, anthropologists, disk, sclc,
# Nearest to some: many, these, several, gheg, most, all, their, any,
# Nearest to an: tychonoff, celebrated, kazantzakis, limbaugh, chocolate, bangs, the, synthesizers,
# Nearest to known: used, such, regarded, seen, envisaged, well, shown, just,
# Nearest to also: often, which, still, not, now, who, festus, sometimes,
# Nearest to he: she, it, they, who, there, largely, i, never,
# Nearest to s: catatonic, serpent, david, his, ur, congestive, stampede, systematic,
# Nearest to from: into, between, in, jay, suspending, weu, serial, trentino,
# Nearest to that: which, however, above, athabasca, this, who, almoravid, what,
# Nearest to into: from, in, between, through, under, zen, trinitarian, before,
# Nearest to war: crony, stimulants, abraham, westernized, appealed, lester, woodford, captors,
# Nearest to after: before, despite, lieutenants, shinoda, penned, appended, trinitarian, bassoon,
# Nearest to than: sufferings, windshield, javan, esb, opiates, rinsing, much, rttemberg,
# Average loss at step 32000: 3.421757
# Average loss at step 34000: 3.440802
# Average loss at step 36000: 3.362682
# Average loss at step 38000: 3.490762
# Average loss at step 40000: 3.447503
# Nearest to its: their, the, his, her, embarked, mannered, receipt, pubmed,
# Nearest to UNK: seniority, descriptions, maturing, vs, infiltrate, mandelstam, legalization, mississippi,
# Nearest to years: times, days, year, generations, chthonic, murder, accumulator, gana,
# Nearest to system: systems, frequencies, disk, network, arnstadt, usmc, scar, dek,
# Nearest to some: many, these, several, gheg, any, all, their, most,
# Nearest to an: tychonoff, kazantzakis, celebrated, the, bonner, bangs, leszek, locally,
# Nearest to known: used, such, regarded, seen, well, envisaged, possible, served,
# Nearest to also: which, often, sometimes, usually, still, now, freiburg, never,
# Nearest to he: it, she, they, who, there, we, but, later,
# Nearest to s: nonstandard, serpent, camus, mehrgarh, his, hinted, prompt, carey,
# Nearest to from: on, into, in, through, between, enlists, under, for,
# Nearest to that: which, however, this, what, who, ascends, joaquim, frivolity,
# Nearest to into: through, from, in, jarvis, under, zen, jung, between,
# Nearest to war: lester, crony, captors, cosmogony, abraham, midshipman, slapped, stimulants,
# Nearest to after: before, during, without, despite, lieutenants, when, while, trinitarian,
# Nearest to than: sufferings, or, javan, isp, ind, windshield, muscovite, much,
# Average loss at step 42000: 3.423440
# Average loss at step 44000: 3.280284
# Average loss at step 46000: 3.408815
# Average loss at step 48000: 3.430414
# Average loss at step 50000: 3.434005
# Nearest to its: their, his, the, her, your, trust, ades, noonan,
# Nearest to UNK: atman, r, neat, otimes, pierre, du, e, dmt,
# Nearest to years: days, times, weeks, year, generations, hours, months, minutes,
# Nearest to system: systems, frequencies, network, disk, mulcahy, draper, sclc, intolerant,
# Nearest to some: many, these, several, any, gheg, their, all, most,
# Nearest to an: limbaugh, bonner, strangely, siberian, tychonoff, leprosy, kazantzakis, funakoshi,
# Nearest to known: used, regarded, possible, such, seen, promoted, referred, considered,
# Nearest to also: often, which, usually, sometimes, still, now, generally, who,
# Nearest to he: she, it, they, there, who, we, cantor, suborders,
# Nearest to s: nonstandard, and, his, ballast, refuelling, mehrgarh, zum, isbn,
# Nearest to from: through, in, into, between, by, under, on, trentino,
# Nearest to that: which, however, what, athabasca, this, where, because, dukedom,
# Nearest to into: through, from, under, jarvis, with, between, within, spawn,
# Nearest to war: crony, captors, midshipman, lester, monarchs, abraham, doctrines, stimulants,
# Nearest to after: before, during, despite, without, when, lieutenants, trinitarian, later,
# Nearest to than: much, sufferings, or, horticulture, far, windshield, yeltsin, javan,
# Average loss at step 52000: 3.455616
# Average loss at step 54000: 3.436685
# Average loss at step 56000: 3.403006
# Average loss at step 58000: 3.281758
# Average loss at step 60000: 3.382431
# Nearest to its: their, his, her, the, noonan, hitch, doublespeak, trust,
# Nearest to UNK: tui, le, exarchate, j, p, www, rh, et,
# Nearest to years: days, times, months, year, weeks, minutes, chthonic, hours,
# Nearest to system: systems, frequencies, disk, paws, goidelic, network, intolerant, refreshed,
# Nearest to some: many, these, all, several, any, gheg, the, most,
# Nearest to an: tychonoff, limbaugh, malarial, siberian, iudex, another, strangely, leszek,
# Nearest to known: used, regarded, possible, such, considered, seen, referred, promoted,
# Nearest to also: which, often, generally, now, still, who, sometimes, never,
# Nearest to he: she, it, they, there, who, eventually, cantor, suborders,
# Nearest to s: friedrich, congestive, refuelling, whose, serpent, nonstandard, camus, remey,
# Nearest to from: through, into, in, since, on, among, including, enlists,
# Nearest to that: which, what, however, this, athabasca, how, menial, above,
# Nearest to into: through, from, jarvis, under, including, within, between, stoic,
# Nearest to war: crony, captors, midshipman, cosmogony, wins, pergamon, monarchs, rights,
# Nearest to after: before, during, when, despite, since, while, following, without,
# Nearest to than: or, slightly, sufferings, horticulture, windshield, ind, muscovite, esb,
# Average loss at step 62000: 3.442016
# Average loss at step 64000: 3.363365
# Average loss at step 66000: 3.344576
# Average loss at step 68000: 3.384251
# Average loss at step 70000: 3.373583
# Nearest to its: their, his, the, her, fusing, bored, hollandic, several,
# Nearest to UNK: tui, luxembourg, intransitive, chartres, named, emptying, headers, pectoral,
# Nearest to years: days, times, months, weeks, hours, chthonic, minutes, year,
# Nearest to system: systems, disk, network, frequencies, refreshed, sclc, intolerant, usmc,
# Nearest to some: many, these, several, all, most, any, those, gheg,
# Nearest to an: another, tychonoff, occupational, malarial, kazantzakis, bangs, limbaugh, bonner,
# Nearest to known: used, regarded, such, considered, referred, seen, possible, understood,
# Nearest to also: now, still, often, which, generally, sometimes, never, usually,
# Nearest to he: she, it, they, there, who, cantor, we, successfully,
# Nearest to s: isbn, refuelling, camus, friedrich, his, zum, whose, lovable,
# Nearest to from: through, into, in, including, since, by, during, globular,
# Nearest to that: which, however, what, but, athabasca, menial, lofty, where,
# Nearest to into: through, from, under, within, across, jung, including, towards,
# Nearest to war: crony, captors, pergamon, unregistered, during, woodford, tley, poodle,
# Nearest to after: before, during, following, despite, while, without, when, since,
# Nearest to than: or, slightly, ind, and, hours, sufferings, much, horticulture,
# Average loss at step 72000: 3.406482
# Average loss at step 74000: 3.388179
# Average loss at step 76000: 3.349983
# Average loss at step 78000: 3.232140
# Average loss at step 80000: 3.371657
# Nearest to its: their, his, the, her, fusing, alum, hollandic, whose,
# Nearest to UNK: depicting, seagram, etching, crispus, sarcophagi, dukkha, dan, n,
# Nearest to years: days, times, months, year, decades, weeks, minutes, hours,
# Nearest to system: systems, disk, network, usmc, sclc, affirmative, walsh, frequencies,
# Nearest to some: many, several, these, most, any, both, those, certain,
# Nearest to an: occupational, limbaugh, the, kazantzakis, lyceum, fasting, malarial, cmf,
# Nearest to known: used, possible, regarded, seen, considered, referred, such, understood,
# Nearest to also: still, now, often, which, usually, never, sometimes, generally,
# Nearest to he: she, it, they, there, who, we, cantor, effectively,
# Nearest to s: carey, nonstandard, whose, refuelling, manure, isbn, and, camus,
# Nearest to from: through, into, since, between, among, during, conjectural, under,
# Nearest to that: which, however, athabasca, joaquim, but, what, this, above,
# Nearest to into: through, from, across, under, jung, jarvis, conscious, boz,
# Nearest to war: crony, wars, captors, during, woodford, cofinal, cosmogony, tley,
# Nearest to after: before, during, without, when, despite, following, since, trinitarian,
# Nearest to than: or, slightly, ind, horticulture, sufferings, ibiblio, much, even,
# Average loss at step 82000: 3.300115
# Average loss at step 84000: 3.341104
# Average loss at step 86000: 3.345859
# Average loss at step 88000: 3.322234
# Average loss at step 90000: 3.240820
# Nearest to its: their, his, her, fusing, hitch, your, whose, several,
# Nearest to UNK: tui, atman, pierre, selina, ernst, aelius, politician, martin,
# Nearest to years: days, year, months, decades, weeks, times, minutes, hours,
# Nearest to system: systems, disk, clones, usmc, network, musketeers, sclc, affirmative,
# Nearest to some: many, several, these, any, gheg, most, those, certain,
# Nearest to an: limbaugh, another, bangs, tychonoff, funakoshi, stabbed, cip, occupational,
# Nearest to known: used, regarded, seen, possible, such, promoted, referred, considered,
# Nearest to also: often, now, still, which, never, who, sometimes, generally,
# Nearest to he: she, it, they, there, who, but, we, quickly,
# Nearest to s: his, refuelling, camus, her, zum, nonstandard, whose, renault,
# Nearest to from: through, into, including, in, suspending, while, until, minerva,
# Nearest to that: which, what, however, athabasca, frivolity, vanquish, ferromagnetic, dukedom,
# Nearest to into: through, from, under, across, jung, back, towards, around,
# Nearest to war: crony, wars, captors, woodford, perpetuate, cofinal, rapper, wins,
# Nearest to after: before, during, without, when, following, despite, until, while,
# Nearest to than: or, slightly, no, ussachevsky, ind, much, hausa, oven,
# Average loss at step 92000: 2.731693
# Average loss at step 94000: 3.101307
# Average loss at step 96000: 3.064581
# Average loss at step 98000: 3.220522
# Average loss at step 100000: 3.282379
# Nearest to its: their, his, her, the, fusing, whose, your, several,
# Nearest to UNK: underwent, hank, tui, petsamo, pierre, ashton, www, savoy,
# Nearest to years: days, months, decades, year, weeks, times, minutes, centuries,
# Nearest to system: systems, disk, usmc, clones, sclc, rashi, daemons, affirmative,
# Nearest to some: many, these, any, several, those, gheg, both, most,
# Nearest to an: another, bangs, limbaugh, carracci, fragmentary, tychonoff, chocolate, categorization,
# Nearest to known: used, regarded, possible, seen, promoted, such, referred, considered,
# Nearest to also: often, now, still, never, sometimes, actually, generally, rarely,
# Nearest to he: she, they, it, there, but, we, who, eventually,
# Nearest to s: his, whose, inline, refuelling, isbn, ur, ballast, mohs,
# Nearest to from: through, conjectural, into, under, without, before, minerva, since,
# Nearest to that: which, however, what, athabasca, this, often, who, joaquim,
# Nearest to into: through, across, under, back, from, towards, rotates, affront,
# Nearest to war: wars, woodford, captors, crony, treaty, rapper, perpetuate, wins,
# Nearest to after: before, despite, when, during, without, following, while, alejandro,
# Nearest to than: or, slightly, much, no, hausa, but, ussachevsky, horticulture,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
